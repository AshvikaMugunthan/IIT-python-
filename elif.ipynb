# %%
marks=int(input("enter your marks?"))
if marks>=75:
    print("Grade A")
elif marks>=65:
    print("Grade B")
elif marks>=50:
    print("Grade C")
else:
    print("Grade F")
# Out:
# enter your marks? 54
# Grade C

# %%
name=str(input("Enter your Name:"))
marks=int(input("Enter your Marks:"))
if 100>=marks>=75:
    print(name,",Your Marks is",marks,"You got Grade D")
elif marks>=65:
     print(name,",Your Marks is",marks,"You got Grade C")
elif marks>=50:
     print(name,",Your Marks is",marks,"You got Grade B")
else:
     print(name,",Your Marks is",marks,"You're failed")
# Out:
# Enter your Name: Ashvika
# Enter your Marks: 85
# Ashvika ,Your Marks is 85 You got Grade D

# %%
x=10
y=20
if x>5:
    if y>10:
        print("Both conditions are true")
    else:
        print("Only x>5 is true")
else:
    print("x is not greater thaan 5")
# Out:
# Both conditions are true

# %%
marks=int(input("enter your marks"))
if 100>=marks and marks>=90:
    print("A")
elif marks>=80:
    print("B")
elif marks>=70:
    print("C")
elif marks>=60:
    print("D")
elif marks>0:
    print("F")
else:
    print("Your input is invalid")
# Out:
# enter your marks 120
# B
