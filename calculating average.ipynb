# %%
first_name=input("enter the first name?")
second_name=input("enter the second name?")
subject1=int(input("Enter the sub 1 marks ?"))
subject2=int(input("Enter the sub 2 marks ?"))
subject3=int(input("Enter the sub 3 marks ?"))
subject4=int(input("Enter the sub 4 marks ?"))
total=subject1+subject2+subject3+subject4
average=total/4

print(first_name)
print(second_name)
print(subject1)
print(subject2)
print(subject3)
print(subject4)
print(total)
print(average)
# Out:
# enter the first name? Ashvika
# enter the second name? Mugunthan
# Enter the sub 1 marks ? 78
# Enter the sub 2 marks ? 87
# Enter the sub 3 marks ? 98
# Enter the sub 4 marks ? 95
# Ashvika
# Mugunthan
# 78
# 87
# 98
# 95
# 358
# 89.5
